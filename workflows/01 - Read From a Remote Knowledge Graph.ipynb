# %%
from kgx import Transformer, NeoTransformer, PandasTransformer
# Out:
# /Users/deepak.unni3/GIT/kgx/test/lib/python3.6/site-packages/cachier/mongo_core.py:24: UserWarning: Cachier warning: pymongo was not found. MongoDB cores will not work.
#   "Cachier warning: pymongo was not found. MongoDB cores will not work.")

# %%
# Monarch-Lite

# Credentials can be found from 'Registry of Biolink-compatible Neo4 instances' spreadsheet
monarch_uri = ''
monarch_username = ''
monarch_password = ''

# Initialize NeoTransformer
monarch_lite_transformer = NeoTransformer(uri=monarch_uri, username=monarch_username, password=monarch_password)

# %%
# Define filters
monarch_lite_transformer.set_filter("subject_category", "gene")
monarch_lite_transformer.set_filter("object_category", "disease")
monarch_lite_transformer.set_filter("edge_label", "contributes_to")

# %%
# Load nodes and edges from Monarch-Lite
start = 0
end = 5000
monarch_lite_transformer.load(start=start, end=end)
monarch_lite_transformer.report()
# Out:
# 2018-06-08 18:40:06,916 root       DEBUG      MATCH (n:gene:disease ) RETURN n SKIP 0 LIMIT 1000;
# 2018-06-08 18:40:07,018 root       DEBUG      MATCH (s:gene)-[p:contributes_to ]->(o:disease)
#             RETURN s,p,o
#             SKIP 0 LIMIT 1000;
# 2018-06-08 18:40:07,620 root       DEBUG      MATCH (s:gene)-[p:contributes_to ]->(o:disease)
#             RETURN s,p,o
#             SKIP 1000 LIMIT 1000;
# 2018-06-08 18:40:08,211 root       DEBUG      MATCH (s:gene)-[p:contributes_to ]->(o:disease)
#             RETURN s,p,o
#             SKIP 2000 LIMIT 1000;
# 2018-06-08 18:40:08,831 root       DEBUG      MATCH (s:gene)-[p:contributes_to ]->(o:disease)
#             RETURN s,p,o
#             SKIP 3000 LIMIT 1000;
# 2018-06-08 18:40:09,535 root       DEBUG      MATCH (s:gene)-[p:contributes_to ]->(o:disease)
#             RETURN s,p,o
#             SKIP 4000 LIMIT 1000;
# Total number of nodes: 5179
# Total number of edges: 5000

# %%
# Show the first 10 nodes from the networkx graph
monarch_lite_transformer.graph.nodes(data=True)[0:9]
# Out:
# [('NCBIGene:38903500',
#   {'iri': 'http://www.ncbi.nlm.nih.gov/gene/38903500',
#    'clique': ['NCBIGene:38903500'],
#    'name': 'KDSR',
#    'http://www.w3.org/2000/01/rdf-schema#label': 'KDSR',
#    'id': 'NCBIGene:38903500',
#    'label': 'KDSR',
#    'category': ['gene', 'sequence feature'],
#    'labels': ['Class', 'sequence_feature', 'gene', 'cliqueLeader', 'Node']}),
#  ('OMIA:000939-9913',
#   {'iri': 'http://purl.obolibrary.org/obo/OMIA_000939-9913',
#    'clique': ['OMIA:000939-9913'],
#    'http://purl.org/dc/elements/1.1/description': 'By examining three comparative positional candidate genes from their mapping results (see Mapping section), Krebs et al. (2007) reported strong evidence that this disorder in cattle is due to a mutation in "FVT1, encoding 3-ketodihydrosphingosine reductase, which catalyzes a crucial step in the glycosphingolipid metabolism". Specifically, the mutation is "a G-to-A missense mutation that changes Ala-175 to Thr". Interestingly, this is not the same gene which, when mutated, results in SMA in humans.\nIn their table of reduced-fertility haplotypes, Cole et al. (2014) list this KDSR mutation as being the causal mutation for haplotype BHM, which is located at 62,118,139��� 62,156,760bp on chromosome BTA24. [mol_gen]',
#    'name': 'Haplotype BHM',
#    'http://www.w3.org/2000/01/rdf-schema#label': 'Haplotype BHM',
#    'id': 'OMIA:000939-9913',
#    'label': 'Haplotype BHM',
#    'category': 'disease',
#    'labels': ['Class', 'Node', 'cliqueLeader', 'disease']}),
#  ('NCBIGene:389756176',
#   {'iri': 'http://www.ncbi.nlm.nih.gov/gene/389756176',
#    'clique': ['NCBIGene:389756176'],
#    'name': 'TMEM154',
#    'http://www.w3.org/2000/01/rdf-schema#label': 'TMEM154',
#    'id': 'NCBIGene:389756176',
#    'label': 'TMEM154',
#    'category': ['gene', 'sequence feature'],
#    'labels': ['Class', 'sequence_feature', 'gene', 'cliqueLeader', 'Node']}),
#  ('OMIA:001694-9940',
#   {'iri': 'http://purl.obolibrary.org/obo/OMIA_001694-9940',
#    'clique': ['OMIA:001694-9940'],
#    'http://purl.org/dc/elements/1.1/description': ['Following up the results of their GWAS described above, Heaton et al. (2012) showed that the two OAR17 SNPs are located in "an ovine gene homologous to the human TMEM154 gene". Subsequent sequencing and association analysis showed that "Two TMEM154 haplotypes encoding glutamate (E) at position 35 were associated with infection.  . . .  The odds of infection for ewes with one copy of a full-length TMEM154 E35 allele were 28 times greater than the odds for those without (p-value<0.0001, 95% CI 5���1,100). In a combined analysis of nine cohorts with 2,705 sheep from Nebraska, Idaho, and Iowa, the relative risk of infection was 2.85 times greater for sheep with a full-length TMEM154 E35 allele (p-value<0.0001, 95% CI 2.36���3.43). Although rare, some sheep were homozygous for TMEM154 deletion mutations and remained uninfected despite a lifetime of significant exposure." Taken together, these results led to Heaton et al. (2012) concluding that "TMEM154 may play a central role in ovine lentivirus infection and removing sheep with the most susceptible genotypes may help eradicate OPP and protect flocks from reinfection". While the actual function of the membrane protein encoded by TMEM154 is still to be worked out, the apparent resistance of sheep homozygous for a mutant that results in no functional peptide strongly suggests a mechanism for resistance/susceptibility, namely that the lentivirus needs this peptide in order to infect cells.\nFollowing up one of the most promising regions for control of infection from the GWAS of White et al. (2012), White et al. (2013) "identified a small insertion/deletion variant near [5\' of] ZNF389 [OVA20; g.29500068_29500069delAT; GenBank NC_019477.1] that showed consistent association with proviral concentration in three animal sets . . . The best estimate of proviral concentration by genotype, obtained from all 1310 OvLV-positive animals tested, showed insertion homozygotes had less than half the proviral concentration of other genotypes (P < 0.0001).  . . . To our knowledge, this is the first genetic variant consistently associated with host control of OvLV post-infection in multiple sheep flocks." [mol_gen]',
#     'As reported by Heaton et al. (2013), "The first signs of disease typically appear after age two and often include the loss of body condition and indurative mastitis (hard udder). Disease progression is associated with severe clinical signs that include difficulty breathing, chronic wasting, loss of motor control, and arthritis." [clin_feat]'],
#    'name': 'Resistance/susceptibility to Visna/Maedi virus (VMV); Resist',
#    'http://www.w3.org/2000/01/rdf-schema#label': 'Resistance/susceptibility to Visna/Maedi virus (VMV); Resist',
#    'id': 'OMIA:001694-9940',
#    'label': 'Resistance/susceptibility to Visna/Maedi virus (VMV); Resist',
#    'category': 'disease',
#    'labels': ['Class', 'Node', 'cliqueLeader', 'disease']}),
#  ('NCBIGene:200685841',
#   {'iri': 'http://www.ncbi.nlm.nih.gov/gene/200685841',
#    'clique': ['NCBIGene:200685841'],
#    'name': 'ABO',
#    'http://www.w3.org/2000/01/rdf-schema#label': 'ABO',
#    'id': 'NCBIGene:200685841',
#    'label': 'ABO',
#    'category': ['gene', 'sequence feature'],
#    'labels': ['Class', 'sequence_feature', 'gene', 'cliqueLeader', 'Node']}),
#  ('OMIA:001089-9590',
#   {'iri': 'http://purl.obolibrary.org/obo/OMIA_001089-9590',
#    'clique': ['OMIA:001089-9590'],
#    'name': 'Blood group system ABO in siamang',
#    'http://www.w3.org/2000/01/rdf-schema#label': 'Blood group system ABO in siamang',
#    'id': 'OMIA:001089-9590',
#    'label': 'Blood group system ABO in siamang',
#    'category': 'disease',
#    'labels': ['Class', 'Node', 'cliqueLeader', 'disease']}),
#  ('NCBIGene:403511',
#   {'iri': 'http://www.ncbi.nlm.nih.gov/gene/403511',
#    'clique': ['NCBIGene:403511', 'ENSEMBL:ENSCAFG00000014655'],
#    'synonym': ['transducin beta chain 3',
#     'guanine nucleotide-binding protein G(I)/G(S)/G(T) subunit beta-3',
#     'transducin beta-3-subunit',
#     'G protein subunit beta 3',
#     'GTP-binding protein beta-3 subunit short isoform'],
#    'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'G protein subunit beta 3',
#    'http://purl.org/dc/elements/1.1/description': 'G protein subunit beta 3',
#    'name': 'GNB3',
#    'http://www.w3.org/2000/01/rdf-schema#label': 'GNB3',
#    'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['transducin beta chain 3',
#     'guanine nucleotide-binding protein G(I)/G(S)/G(T) subunit beta-3',
#     'transducin beta-3-subunit',
#     'GTP-binding protein beta-3 subunit short isoform'],
#    'id': 'NCBIGene:403511',
#    'label': 'GNB3',
#    'category': ['gene', 'sequence feature'],
#    'labels': ['Class', 'sequence_feature', 'gene', 'cliqueLeader', 'Node']}),
#  ('OMIA:001244-9615',
#   {'iri': 'http://purl.obolibrary.org/obo/OMIA_001244-9615',
#    'clique': ['OMIA:001244-9615'],
#    'name': 'Retinal degeneration II in dog',
#    'http://www.w3.org/2000/01/rdf-schema#label': 'Retinal degeneration II in dog',
#    'id': 'OMIA:001244-9615',
#    'label': 'Retinal degeneration II in dog',
#    'category': 'disease',
#    'labels': ['Class', 'Node', 'cliqueLeader', 'disease']}),
#  ('NCBIGene:403972',
#   {'iri': 'http://www.ncbi.nlm.nih.gov/gene/403972',
#    'synonym': ['retinal degeneration slow protein',
#     'RDS',
#     'peripherin 2',
#     'peripherin protein',
#     'peripherin-2',
#     'retinal degeneration, slow',
#     'rds gene for peripherin'],
#    'clique': ['NCBIGene:403972', 'ENSEMBL:ENSCAFG00000001722'],
#    'http://www.geneontology.org/formats/oboInOwl#hasExactSynonym': 'peripherin 2',
#    'http://purl.org/dc/elements/1.1/description': 'peripherin 2',
#    'name': 'PRPH2',
#    'http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym': ['retinal degeneration slow protein',
#     'RDS',
#     'peripherin protein',
#     'peripherin-2',
#     'retinal degeneration, slow',
#     'rds gene for peripherin'],
#    'http://www.w3.org/2000/01/rdf-schema#label': 'PRPH2',
#    'id': 'NCBIGene:403972',
#    'label': 'PRPH2',
#    'category': ['gene', 'sequence feature'],
#    'labels': ['Class', 'sequence_feature', 'gene', 'cliqueLeader', 'Node']})]

# %%
# Show the first 10 edges from the networkx graph
monarch_lite_transformer.graph.edges(data=True)[0:9]
# Out:
# [('NCBIGene:38903500',
#   'OMIA:000939-9913',
#   {'is_defined_by': 'Monarch',
#    'provided_by': ['https://data.monarchinitiative.org/ttl/omia.ttl'],
#    'evidence': [],
#    'qualifier': 'direct',
#    'publications': [],
#    'relation': 'RO:0002326',
#    'subject': 'NCBIGene:38903500',
#    'object': 'OMIA:000939-9913',
#    'id': 3400163,
#    'type': 'contributes_to',
#    'predicate': 'contributes_to'}),
#  ('NCBIGene:389756176',
#   'OMIA:001694-9940',
#   {'is_defined_by': 'Monarch',
#    'provided_by': ['https://data.monarchinitiative.org/ttl/omia.ttl'],
#    'evidence': [],
#    'qualifier': 'direct',
#    'publications': [],
#    'relation': 'RO:0002326',
#    'subject': 'NCBIGene:389756176',
#    'object': 'OMIA:001694-9940',
#    'id': 3269874,
#    'type': 'contributes_to',
#    'predicate': 'contributes_to'}),
#  ('NCBIGene:200685841',
#   'OMIA:001089-9590',
#   {'is_defined_by': 'Monarch',
#    'provided_by': ['https://data.monarchinitiative.org/ttl/omia.ttl'],
#    'evidence': [],
#    'qualifier': 'direct',
#    'publications': [],
#    'relation': 'RO:0002326',
#    'subject': 'NCBIGene:200685841',
#    'object': 'OMIA:001089-9590',
#    'id': 3948919,
#    'type': 'contributes_to',
#    'predicate': 'contributes_to'}),
#  ('NCBIGene:403511',
#   'OMIA:001244-9615',
#   {'is_defined_by': 'Monarch',
#    'provided_by': ['https://data.monarchinitiative.org/ttl/omia.ttl'],
#    'evidence': [],
#    'qualifier': 'direct',
#    'publications': [],
#    'relation': 'RO:0002326',
#    'subject': 'NCBIGene:403511',
#    'object': 'OMIA:001244-9615',
#    'id': 4024483,
#    'type': 'contributes_to',
#    'predicate': 'contributes_to'}),
#  ('NCBIGene:403972',
#   'OMIA:001244-9615',
#   {'is_defined_by': 'Monarch',
#    'provided_by': ['https://data.monarchinitiative.org/ttl/omia.ttl'],
#    'evidence': [],
#    'qualifier': 'direct',
#    'publications': [],
#    'relation': 'RO:0002326',
#    'subject': 'NCBIGene:403972',
#    'object': 'OMIA:001244-9615',
#    'id': 3951300,
#    'type': 'contributes_to',
#    'predicate': 'contributes_to'}),
#  ('NCBIGene:43056830',
#   'OMIA:001089-9598',
#   {'is_defined_by': 'Monarch',
#    'provided_by': ['https://data.monarchinitiative.org/ttl/omia.ttl'],
#    'evidence': [],
#    'qualifier': 'direct',
#    'publications': [],
#    'relation': 'RO:0002326',
#    'subject': 'NCBIGene:43056830',
#    'object': 'OMIA:001089-9598',
#    'id': 3750612,
#    'type': 'contributes_to',
#    'predicate': 'contributes_to'}),
#  ('NCBIGene:38908820',
#   'OMIA:001450-9913',
#   {'is_defined_by': 'Monarch',
#    'provided_by': ['https://data.monarchinitiative.org/ttl/omia.ttl'],
#    'evidence': [],
#    'qualifier': 'direct',
#    'publications': [],
#    'relation': 'RO:0002326',
#    'subject': 'NCBIGene:38908820',
#    'object': 'OMIA:001450-9913',
#    'id': 4064365,
#    'type': 'contributes_to',
#    'predicate': 'contributes_to'}),
#  ('NCBIGene:38908820',
#   'OMIA:001464-9913',
#   {'is_defined_by': 'Monarch',
#    'provided_by': ['https://data.monarchinitiative.org/ttl/omia.ttl'],
#    'evidence': [],
#    'qualifier': 'direct',
#    'publications': [],
#    'relation': 'RO:0002326',
#    'subject': 'NCBIGene:38908820',
#    'object': 'OMIA:001464-9913',
#    'id': 3830535,
#    'type': 'contributes_to',
#    'predicate': 'contributes_to'}),
#  ('NCBIGene:199226050',
#   'OMIA:001089-9579',
#   {'is_defined_by': 'Monarch',
#    'provided_by': ['https://data.monarchinitiative.org/ttl/omia.ttl'],
#    'evidence': [],
#    'qualifier': 'direct',
#    'publications': [],
#    'relation': 'RO:0002326',
#    'subject': 'NCBIGene:199226050',
#    'object': 'OMIA:001089-9579',
#    'id': 4154152,
#    'type': 'contributes_to',
#    'predicate': 'contributes_to'})]

# %%
# Create a PandasTransformer, required for CSV export
pandas_transformer = PandasTransformer(monarch_lite_transformer.graph)

# export the networkx graph as CSV
pandas_transformer.save("monarch_lite_data.csv")

# You should see monarch_lite_data.csv.tar in your current folder.
# Out:
# 'monarch_lite_data.csv.tar'
